# %% [markdown]
# ### LINEAR REGRESSION MODEL WITH UNSCALED DATA

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
file_path = '/Users/admin/code/derksol/finance/raw_data/data_processed_unscaled.csv'

# Read the CSV file into a DataFrame
df_unscaled = pd.read_csv(file_path)

# Drop the unnamed column in-place
df_unscaled.drop(columns=['Unnamed: 0'], inplace=True)

df_unscaled.head(5)
# Out:
#   symbol        time_frame        date  revenuePerShare  netIncomePerShare  \
# 0  AABPX  2023Q3 vs 2023Q2  2023-06-30         0.061599      -7.090000e-01
# 1  AABPX  2023Q2 vs 2023Q1  2023-03-31         0.145790      -1.591602e+00
# 2  AABPX  2023Q1 vs 2022Q4  2022-12-31        -0.216065      -5.058721e-01
# 3  AABPX  2022Q3 vs 2022Q2  2022-06-30         0.040987       1.639538e-08
# 4  AABPX  2022Q1 vs 2021Q4  2021-12-31        -0.052030       1.061740e+00
#
#    operatingCashFlowPerShare  freeCashFlowPerShare  cashPerShare  \
# 0                  -0.157992             -0.180327     -0.257108
# 1                   0.433673              0.444980     -0.194237
# 2                  -1.405002             -1.449164     -0.033316
# 3                  -4.675824             -9.083313     -0.044171
# 4                  -1.377715             -1.423833      0.108110
#
#    bookValuePerShare  tangibleBookValuePerShare  ...  grahamNumber      roic  \
# ...

# %%
#define X and y features
X = df_unscaled[['revenuePerShare' , 'netIncomePerShare' , 'operatingCashFlowPerShare' , 'freeCashFlowPerShare' , 'cashPerShare' , 'bookValuePerShare' , 'tangibleBookValuePerShare' , 'grahamNumber' , 'roic' , 'returnOnTangibleAssets' , 'grahamNetNet' , 'workingCapital' , 'tangibleAssetValue', 'netCurrentAssetValue' , 'roe']]  #drop symbol, timeframe, date , and close vs market -y target
y = df_unscaled['close_vs_market']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# %%
# Evaluate the model

mae = mean_absolute_error(y_test, predictions)
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 0.12978601053454364
